# %%
import pandas as pd

# %%
alien_data = pd.read_csv("data/sightings_count.csv")

# %%
alien_data
# Out:
#               state_long state_short  sightings_total  Jan  Feb  Mar  Apr  \
# 0                Alabama          AL               34    3    2    4    5
# 1                Arizona          AZ              155   12   20   20   13
# 2               Arkansas          AR               43   10    5    2    3
# 3             California          CA              398   36   49   25   20
# 4               Colorado          CO              116    6   10   12    6
# 5            Connecticut          CT               15    4    0    2    3
# 6               Delaware          DE                7    0    0    2    0
# 7   District of Columbia          DC                8    0    1    0    1
# 8                Florida          FL              250   41   16   25   14
# 9                Georgia          GA               68    5    5    9   10
# 10                 Idaho          ID               36    2    1    2    6
# 11              Illinois          IL               86   12    2    6    3
# ...
